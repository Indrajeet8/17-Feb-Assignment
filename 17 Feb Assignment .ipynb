# %% [markdown]
# # MongoDB

# %% [markdown]
# ## Assignment Questions

# %%
#Q1. what is mongodb non relational databases in short in which scenarias it is preferred to use MongoDB over SQL database

# %% [markdown]
# MongoDB, the most popular NoSQL database, is an open-source document-oriented database. The term 'NoSQL' means 'non-relational'. It means that MongoDB isn't based on the table-like relational database structure but provides an altogether different mechanism for storage and retrieval of data

# %%
#Q2. State and Explain the features of MongoDB.

# %% [markdown]
# It contains heterogeneous data. It provides high performance, availability, scalability. It supports Geospatial efficiently. It is a document oriented database and the data is stored in BSON documents

# %%
#Q3. Write a code to connect MongoDB to Python. Also, create a database and a collection in MongoDB.

# %%
pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 36.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 34.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://pwskills:pwskills@cluster0.ln0bt5m.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
#Q4. Using the database and the collection created in question number 3, write a code to insert one record and insert many records. Use the find() and find_one() methods to print the inserted record.

# %%
#Q5. Explain how you can use the find() method to query the MongoDB database. Write a simple code to demonstrate this.

# %%
db
# Out:
# Database(MongoClient(host=['ac-2blvghl-shard-00-02.ln0bt5m.mongodb.net:27017', 'ac-2blvghl-shard-00-00.ln0bt5m.mongodb.net:27017', 'ac-2blvghl-shard-00-01.ln0bt5m.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-bpwwyw-shard-0', tls=True), 'test')

# %%
client = pymongo.MongoClient("mongodb+srv://pwskills:pwskills@cluster0.ln0bt5m.mongodb.net/?retryWrites=true&w=majority")

# %%
db = client['pwskills']

# %%
data = {"name " : "indrajeet",
        "class" : " data scince " ,
        "time" : "flexi"}

# %%
cell_pwskills = db["my_record"]

# %%
coll_pwskills.insert_one(data)

# %%
data1 = {"ail_id" : "indrajeet725" ,
         "phone_num" : 8303552870 ,
         "addr" : "kannauj" ,}

# %%
cell_pwskills.insert_one(data1)

# %%
 data2 = [
  { "name": "Amy", "address": "Apple st 652" },
  { "name": "Hannah", "address": "Mountain 21" },
  { "name": "Michael", "address": "Valley 345" },
  { "name": "Sandy", "address": "Ocean blvd 2" },
  { "name": "Betty", "address": "Green Grass 1" },
  { "name": "Richard", "address": "Sky st 331" },
  { "name": "Susan", "address": "One way 98" },
  { "name": "Vicky", "address": "Yellow Garden 2" },
  { "name": "Ben", "address": "Park Lane 38" },
  { "name": "William", "address": "Central st 954" },
  { "name": "Chuck", "address": "Main Road 989" },
  { "name": "Viola", "address": "Sideway 1633" }
]

# %%
cell_pwskills.insert_many(data2)

# %%
data3 = {
 "name": "notebook",
 "qty": 50,
 "rating": [ { "score": 8 }, { "score": 9 } ],
 "size": { "height": 11, "width": 8.5, "unit": "in" },
 "status": "A",
 "tags": [ "college-ruled", "perforated"]
}

# %%
cell_pwskills.insert_one(data3)

# %%
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

# %%
cell_pwskills.insert_many(list_of_records)

# %%
cell_pwskills.find_one()
# Out:
# {'_id': ObjectId('63eef93f07ba7bd48aa09a98'),
#  'name': 'sudh',
#  'class': 'data science masters ',
#  'time': 'flexi'}

# %%
for i in cell_pwskills.find() :
    print(i)
# Out:
# {'_id': ObjectId('63eef93f07ba7bd48aa09a98'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('63eef9ea07ba7bd48aa09a99'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9b'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa1'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9a'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9f'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9c'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa0'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9e'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa2'), 'name': 'Ben', 'address': 'Park Lane 38'}
# ...

# %%
#Q6. Explain the sort() method. Give an example to demonstrate sorting in MongoDB.

# %% [markdown]
# The sort() method specifies the order in which the query returns the matching documents from the given collection.

# %%
db.Collection_Name.sort({field_name:1 or -1})
